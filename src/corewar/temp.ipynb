# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np

colors = [f"#{c}" for c in "f94144-f3722c-f8961e-f9844a-f9c74f-90be6d-43aa8b-4d908e-577590-277da1".split("-")]
colors = np.array([mcolors.to_rgb(c) for c in colors])
colors = (colors*255).astype(np.uint8)
colors_dark = colors//2

# %%
a = []
for c1, c2 in zip(colors_dark, colors):
    a.append((tuple(c1), tuple(c2)))
a = tuple(a)

# %%
a
# Out:
# (((124, 32, 34), (249, 65, 68)),
#  ((121, 57, 22), (243, 114, 44)),
#  ((124, 75, 15), (248, 150, 30)),
#  ((124, 66, 37), (249, 132, 74)),
#  ((124, 99, 39), (249, 199, 79)),
#  ((72, 95, 54), (144, 190, 109)),
#  ((33, 85, 69), (67, 170, 139)),
#  ((38, 72, 71), (77, 144, 142)),
#  ((43, 58, 72), (87, 117, 144)),
#  ((19, 62, 80), (39, 125, 161)))

# %%
A = (((0,0,100), (0,0,255)),
                  ((0,100,0), (0,255,0)),
                  ((0,100,100), (0,255,255)),
                  ((100,0,0), (255,0,0)),
                  ((100,0,100), (255,0,255)),
                  ((100,100,0), (255,255,0)))
A = np.array(A)
print(A.shape)
plt.imshow(A.swapaxes(0, 1))
# Out:
# (6, 2, 3)

# %%
A = "ff0000-ff8700-ffd300-deff0a-a1ff0a-0aff99-0aefff-147df5-580aff-be0aff"
A = np.array([mcolors.to_rgb(f"#{c}") for c in A.split("-")])
A = (A*255).astype(np.uint8)
A = np.stack([A//2, A], axis=1)
plt.imshow(A.swapaxes(0, 1)); plt.xticks([]); plt.yticks([])
tuple([(tuple(c1), tuple(c2)) for c1, c2 in A])
# Out:
# (((127, 0, 0), (255, 0, 0)),
#  ((127, 67, 0), (255, 135, 0)),
#  ((127, 105, 0), (255, 211, 0)),
#  ((111, 127, 5), (222, 255, 10)),
#  ((80, 127, 5), (161, 255, 10)),
#  ((5, 127, 76), (10, 255, 153)),
#  ((5, 119, 127), (10, 239, 255)),
#  ((10, 62, 122), (20, 125, 245)),
#  ((44, 5, 127), (88, 10, 255)),
#  ((95, 5, 127), (190, 10, 255)))

# %%
A = "001219-005f73-0a9396-94d2bd-e9d8a6-ee9b00-ca6702-bb3e03-ae2012-9b2226"
A = np.array([mcolors.to_rgb(f"#{c}") for c in A.split("-")])
A = (A*255).astype(np.uint8)
A = np.stack([A//2, A], axis=1)
plt.imshow(A.swapaxes(0, 1)); plt.xticks([]); plt.yticks([])
tuple([(tuple(c1), tuple(c2)) for c1, c2 in A])
# Out:
# (((0, 9, 12), (0, 18, 25)),
#  ((0, 47, 57), (0, 95, 115)),
#  ((5, 73, 75), (10, 147, 150)),
#  ((74, 105, 94), (148, 210, 189)),
#  ((116, 108, 83), (233, 216, 166)),
#  ((119, 77, 0), (238, 155, 0)),
#  ((101, 51, 1), (202, 103, 2)),
#  ((93, 31, 1), (187, 62, 3)),
#  ((87, 16, 9), (174, 32, 18)),
#  ((77, 17, 19), (155, 34, 38)))

# %%
A = "f94144-f3722c-f8961e-f9844a-f9c74f-90be6d-43aa8b-4d908e-577590-277da1"
A = np.array([mcolors.to_rgb(f"#{c}") for c in A.split("-")])
A = (A*255).astype(np.uint8)
A = np.stack([A//2, A], axis=1)
plt.imshow(A.swapaxes(0, 1)); plt.xticks([]); plt.yticks([])
tuple([(tuple(c1), tuple(c2)) for c1, c2 in A])
# Out:
# (((124, 32, 34), (249, 65, 68)),
#  ((121, 57, 22), (243, 114, 44)),
#  ((124, 75, 15), (248, 150, 30)),
#  ((124, 66, 37), (249, 132, 74)),
#  ((124, 99, 39), (249, 199, 79)),
#  ((72, 95, 54), (144, 190, 109)),
#  ((33, 85, 69), (67, 170, 139)),
#  ((38, 72, 71), (77, 144, 142)),
#  ((43, 58, 72), (87, 117, 144)),
#  ((19, 62, 80), (39, 125, 161)))
